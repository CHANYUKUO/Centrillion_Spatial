# %%
from main import BrainAlignmentGUI

#regular spatial example
tif_image_path = '/media/home/ckuo/data_science_project/Brain_alignment_Proj/240806/1/1_Default_Extended.tif'
npy_image_path = '/media/home/ckuo/data_science_project/Brain_alignment_Proj/st_npy/QT-MB-240806-1-5G_mtx.npy.gz'
spatial_dataset=False
#adata object example
#tif_image_path='/media/home/ckuo/data_science_project/drive/pseudo_he.png'
#npy_image_path = '/media/home/ckuo/data_science_project/drive/matrix_xs2500_ys2300_lx2000_2000_b2v4_filtered.h5ad'
#spatial_dataset=True

# %%
# %matplotlib widget
gui = BrainAlignmentGUI(
    tif_image_path, npy_image_path,tif_scale_factor=[0.02,0.2],npy_scale_factor=[0.5,1],spatial_dataset=spatial_dataset
)
gui.run()
# Out:
# Dropdown(description='Tools:', options=('Zoom out', 'Vector Register', 'Run Cellpose', 'Transform Affine', 'Tr…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Estimating....
# Warping....
# Calculating Low Resolution....
# Done!
